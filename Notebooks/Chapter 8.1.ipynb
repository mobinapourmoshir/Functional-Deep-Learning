# %% [markdown]
# <a href="https://colab.research.google.com/github/mobinapourmoshir/Functional-Deep-Learning/blob/main/Notebooks/Chapter%208.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear): # Is the current layer a fully-connected layer
        # He normal initialization Omega ~ N(0, 2/D_h) (kaiming_normal_ func)
        nn.init.kaiming_normal_(layer_in.weight, nonlinearity='relu')
        if layer_in.bias is not None:
            nn.init.zeros_(layer_in.bias) # z = vector of zeros

# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.783206, train error 71.22,  test loss 1.809725, test error 75.50
# Epoch     1, train loss 1.697614, train error 68.32,  test loss 1.725602, test error 72.50
# Epoch     2, train loss 1.664587, train error 66.80,  test loss 1.691564, test error 70.60
# Epoch     3, train loss 1.646458, train error 65.38,  test loss 1.679046, test error 69.30
# Epoch     4, train loss 1.649536, train error 65.50,  test loss 1.698930, test error 69.30
# Epoch     5, train loss 1.630828, train error 65.43,  test loss 1.666753, test error 68.00
# Epoch     6, train loss 1.620050, train error 64.97,  test loss 1.665599, test error 69.80
# Epoch     7, train loss 1.631385, train error 65.65,  test loss 1.673917, test error 67.30
# Epoch     8, train loss 1.621686, train error 64.47,  test loss 1.669929, test error 69.20
# Epoch     9, train loss 1.617891, train error 64.93,  test loss 1.662520, test error 68.20
# Epoch    10, train loss 1.607657, train error 63.92,  test loss 1.659407, test error 67.10
# Epoch    11, train loss 1.600091, train error 63.05,  test loss 1.657702, test error 67.90
# Epoch    12, train loss 1.600590, train error 62.55,  test loss 1.646100, test error 67.60
# Epoch    13, train loss 1.600415, train error 63.38,  test loss 1.657425, test error 66.50
# Epoch    14, train loss 1.599100, train error 62.83,  test loss 1.652387, test error 68.30
# Epoch    15, train loss 1.600087, train error 62.50,  test loss 1.655741, test error 67.20
# Epoch    16, train loss 1.597280, train error 63.62,  test loss 1.656399, test error 67.10
# Epoch    17, train loss 1.599634, train error 63.38,  test loss 1.657012, test error 66.90
# Epoch    18, train loss 1.597263, train error 63.67,  test loss 1.658215, test error 67.80
# Epoch    19, train loss 1.597672, train error 62.88,  test loss 1.657073, test error 67.20
# Epoch    20, train loss 1.594378, train error 63.17,  test loss 1.653607, test error 66.90
# Epoch    21, train loss 1.593743, train error 62.17,  test loss 1.653917, test error 68.00
# Epoch    22, train loss 1.593018, train error 63.20,  test loss 1.656083, test error 68.30
# Epoch    23, train loss 1.592689, train error 62.40,  test loss 1.650304, test error 67.20
# Epoch    24, train loss 1.592457, train error 62.45,  test loss 1.652944, test error 68.60
# Epoch    25, train loss 1.592934, train error 62.58,  test loss 1.651469, test error 68.10
# Epoch    26, train loss 1.592505, train error 62.97,  test loss 1.654823, test error 67.80
# Epoch    27, train loss 1.592128, train error 62.47,  test loss 1.652252, test error 66.90
# Epoch    28, train loss 1.591693, train error 62.15,  test loss 1.651941, test error 68.50
# Epoch    29, train loss 1.591894, train error 62.72,  test loss 1.656076, test error 67.60
# Epoch    30, train loss 1.590911, train error 62.55,  test loss 1.651830, test error 66.90
# Epoch    31, train loss 1.590647, train error 62.53,  test loss 1.653201, test error 67.70
# Epoch    32, train loss 1.590643, train error 62.35,  test loss 1.650846, test error 67.80
# Epoch    33, train loss 1.590458, train error 62.30,  test loss 1.651455, test error 67.50
# Epoch    34, train loss 1.590513, train error 62.38,  test loss 1.654682, test error 67.20
# Epoch    35, train loss 1.590412, train error 62.25,  test loss 1.651768, test error 67.70
# Epoch    36, train loss 1.590431, train error 62.22,  test loss 1.651994, test error 67.70
# Epoch    37, train loss 1.590216, train error 62.40,  test loss 1.651981, test error 67.70
# Epoch    38, train loss 1.590149, train error 62.70,  test loss 1.653848, test error 67.60
# Epoch    39, train loss 1.590073, train error 62.42,  test loss 1.653426, test error 67.90
# Epoch    40, train loss 1.590048, train error 62.10,  test loss 1.652084, test error 68.10
# Epoch    41, train loss 1.589894, train error 62.72,  test loss 1.653015, test error 67.80
# Epoch    42, train loss 1.589854, train error 62.83,  test loss 1.653185, test error 67.50
# Epoch    43, train loss 1.589836, train error 62.42,  test loss 1.652341, test error 67.70
# Epoch    44, train loss 1.589850, train error 62.50,  test loss 1.652321, test error 67.80
# Epoch    45, train loss 1.589805, train error 62.25,  test loss 1.652407, test error 68.20
# Epoch    46, train loss 1.589774, train error 62.62,  test loss 1.653050, test error 67.60
# Epoch    47, train loss 1.589716, train error 62.60,  test loss 1.653157, test error 67.50
# Epoch    48, train loss 1.589697, train error 62.20,  test loss 1.653308, test error 68.20
# Epoch    49, train loss 1.589683, train error 62.45,  test loss 1.652850, test error 67.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
