# %% [markdown]
# <a href="https://colab.research.google.com/github/mobinapourmoshir/Functional-Deep-Learning/blob/main/Notebooks/Chapter%208.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-2eriz_1u
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-2eriz_1u
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=506cd621361158a1111e66fec7185d0250f7db5c7729bb790c0871893660d003
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qfggt30e/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# **1.    At what capacity do you think the training error will become zero?**
# Idea: A fully-connected network can memorize the training set once the number of trainable parameters ≈ number of training examples.
#
# Action: compute the total number of parameters P in the network as a function of the hidden-unit size (or other capacity control). Solve for the capacity where $P≈N$ (here $N=4000$). That capacity is where you expect training error to hit zero (or very close).
#
# General formula for a 2-hidden-layer fully connected net
# Let:
#
# $d_{in}$ = input dimension (features),
#
# $H$ = number of hidden units per hidden layer (assume same for both layers),
#
# $d_{out}$ = output dimension (classes / scalar output).
#
# Then number of weight parameters (ignore tiny bias count if you want a simple approx):
#
# $$P≈d_{in}⋅H+H⋅H+H⋅d_{out}$$
#
# (You can add $+H+H+d_{out}$ for biases if you want exact.)
#
# Solve $P(H)≈4000$ for $H$. $$P(H)= 40H+H+H^2+H+2H+2 = 4000 ⟶ H ≈ 45.3$$
#
# ------
# **2.   At what capacity do you expect the first minima of the double descent curve to appear?**
# Idea: The first minimum is typically the best test performance you can get in the under-parameterized regime — when the model is flexible enough to capture the main signal but not so flexible that it overfits noise. This usually occurs at a capacity smaller than the interpolation threshold.
#
# Actionable approach:
#
# Compute bias/variance intuition: start from small H and increase — the first minimum usually appears where the test error is lowest before the interpolation peak (so often at some $H$ where $P(H)≪N$ or moderately less than $N$).
#
# To predict it numerically you can:compute  $P(H)$ for a range of $H$;
#
# expect the first minimum at a capacity where the model can represent the true signal complexity (depends on the problem), often where $P(H)$ is a few hundred(s) for many simple toy tasks — but this is problem dependent.
#
# Conclusion: you cannot get an exact number without knowing the target function / signal complexity, but you can bracket it: it will be before the interpolation threshold and usually where the training error is low but not zero.
#
# -----
# **3. At what capacity do you expect the maximum of the double descent curve to appear?**
# Idea: The classical bias-variance story predicts the test error peaks near the point where the model just becomes able to perfectly fit / memorize the training set. That occurs when  $P≈N$ (the interpolation threshold).
#
# Action: Using the same parameter count formula, the maximum is expected around the capacity where $P(H)≈4000$. In practice the peak is often within the neighborhood of that $H$ (a little lower or higher), but this is the right place to look.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.290170, train error 88.00,  test loss 2.285181, test error 87.05
# Epoch   100, train loss 1.873432, train error 70.90,  test loss 1.715058, test error 68.82
# Epoch   200, train loss 1.861247, train error 70.47,  test loss 1.704424, test error 68.20
# Epoch   300, train loss 1.866240, train error 71.32,  test loss 1.700953, test error 69.70
# Epoch   400, train loss 1.851553, train error 69.90,  test loss 1.697925, test error 67.82
# Epoch   500, train loss 1.849262, train error 69.53,  test loss 1.697229, test error 67.93
# Epoch   600, train loss 1.848445, train error 70.07,  test loss 1.692289, test error 68.15
# Epoch   700, train loss 1.848819, train error 69.90,  test loss 1.696131, test error 68.05
# Epoch   800, train loss 1.848095, train error 69.90,  test loss 1.693242, test error 68.40
# Epoch   900, train loss 1.850583, train error 69.82,  test loss 1.698297, test error 68.18
# Training model with   4 hidden variables
# Epoch     0, train loss 2.287642, train error 87.65,  test loss 2.289625, test error 89.00
# Epoch   100, train loss 1.859192, train error 69.18,  test loss 1.734731, test error 68.40
# Epoch   200, train loss 1.754024, train error 64.57,  test loss 1.567914, test error 62.00
# Epoch   300, train loss 1.747787, train error 64.35,  test loss 1.565229, test error 60.70
# Epoch   400, train loss 1.749497, train error 64.07,  test loss 1.566366, test error 62.15
# Epoch   500, train loss 1.744461, train error 64.07,  test loss 1.576298, test error 61.80
# Epoch   600, train loss 1.744154, train error 64.65,  test loss 1.567818, test error 61.78
# Epoch   700, train loss 1.752388, train error 64.78,  test loss 1.577011, test error 62.38
# Epoch   800, train loss 1.741278, train error 64.47,  test loss 1.574758, test error 61.85
# Epoch   900, train loss 1.747173, train error 64.25,  test loss 1.570953, test error 62.28
# Training model with   6 hidden variables
# Epoch     0, train loss 2.261608, train error 85.38,  test loss 2.248677, test error 83.90
# Epoch   100, train loss 1.701817, train error 62.20,  test loss 1.521849, test error 59.12
# Epoch   200, train loss 1.686040, train error 62.10,  test loss 1.518876, test error 59.22
# Epoch   300, train loss 1.674532, train error 61.80,  test loss 1.524377, test error 60.00
# Epoch   400, train loss 1.673212, train error 61.55,  test loss 1.527540, test error 59.95
# Epoch   500, train loss 1.670276, train error 60.85,  test loss 1.535101, test error 60.12
# Epoch   600, train loss 1.664114, train error 61.15,  test loss 1.524243, test error 59.28
# Epoch   700, train loss 1.664216, train error 60.25,  test loss 1.528901, test error 59.67
# Epoch   800, train loss 1.660388, train error 60.50,  test loss 1.527511, test error 59.55
# Epoch   900, train loss 1.663210, train error 60.58,  test loss 1.523522, test error 59.38
# Training model with   8 hidden variables
# Epoch     0, train loss 2.278296, train error 87.90,  test loss 2.278846, test error 86.93
# Epoch   100, train loss 1.629725, train error 58.45,  test loss 1.495561, test error 58.62
# Epoch   200, train loss 1.581920, train error 57.08,  test loss 1.464972, test error 55.83
# Epoch   300, train loss 1.561924, train error 55.72,  test loss 1.457808, test error 55.75
# Epoch   400, train loss 1.545996, train error 55.62,  test loss 1.452222, test error 55.38
# Epoch   500, train loss 1.534564, train error 54.78,  test loss 1.455062, test error 54.70
# Epoch   600, train loss 1.526224, train error 54.40,  test loss 1.458896, test error 55.40
# Epoch   700, train loss 1.520641, train error 54.45,  test loss 1.460557, test error 55.28
# Epoch   800, train loss 1.519080, train error 54.47,  test loss 1.466201, test error 55.75
# Epoch   900, train loss 1.513382, train error 54.00,  test loss 1.471445, test error 55.12
# Training model with  10 hidden variables
# Epoch     0, train loss 2.235591, train error 83.93,  test loss 2.201385, test error 83.47
# Epoch   100, train loss 1.504344, train error 51.08,  test loss 1.332386, test error 50.10
# Epoch   200, train loss 1.453687, train error 49.30,  test loss 1.282092, test error 47.28
# Epoch   300, train loss 1.423194, train error 47.67,  test loss 1.298676, test error 47.78
# Epoch   400, train loss 1.411895, train error 47.65,  test loss 1.304148, test error 48.35
# Epoch   500, train loss 1.399573, train error 47.47,  test loss 1.303206, test error 47.75
# Epoch   600, train loss 1.393632, train error 47.35,  test loss 1.315546, test error 48.83
# Epoch   700, train loss 1.392770, train error 47.60,  test loss 1.324747, test error 48.85
# Epoch   800, train loss 1.384050, train error 47.12,  test loss 1.328076, test error 48.65
# Epoch   900, train loss 1.387728, train error 47.72,  test loss 1.343349, test error 49.38
# Training model with  14 hidden variables
# Epoch     0, train loss 2.303073, train error 87.93,  test loss 2.296906, test error 86.82
# Epoch   100, train loss 1.481514, train error 50.67,  test loss 1.394298, test error 52.12
# Epoch   200, train loss 1.408144, train error 47.22,  test loss 1.388348, test error 51.62
# Epoch   300, train loss 1.367135, train error 46.60,  test loss 1.383782, test error 51.10
# Epoch   400, train loss 1.332191, train error 44.22,  test loss 1.394378, test error 51.42
# Epoch   500, train loss 1.320082, train error 44.80,  test loss 1.406163, test error 51.25
# Epoch   600, train loss 1.310088, train error 43.60,  test loss 1.405358, test error 51.40
# Epoch   700, train loss 1.301126, train error 43.92,  test loss 1.424534, test error 51.40
# Epoch   800, train loss 1.294184, train error 43.55,  test loss 1.433526, test error 51.67
# Epoch   900, train loss 1.289593, train error 43.25,  test loss 1.431254, test error 51.33
# Training model with  18 hidden variables
# Epoch     0, train loss 2.140956, train error 81.12,  test loss 2.085654, test error 79.20
# Epoch   100, train loss 1.386113, train error 46.28,  test loss 1.375426, test error 52.17
# Epoch   200, train loss 1.267937, train error 41.97,  test loss 1.382934, test error 50.70
# Epoch   300, train loss 1.223948, train error 40.65,  test loss 1.416803, test error 51.45
# Epoch   400, train loss 1.198203, train error 39.38,  test loss 1.457975, test error 51.65
# Epoch   500, train loss 1.181392, train error 39.10,  test loss 1.479370, test error 51.53
# Epoch   600, train loss 1.162039, train error 38.75,  test loss 1.527351, test error 52.30
# Epoch   700, train loss 1.161459, train error 39.03,  test loss 1.580246, test error 52.17
# Epoch   800, train loss 1.150552, train error 38.70,  test loss 1.601687, test error 52.08
# Epoch   900, train loss 1.149959, train error 38.97,  test loss 1.623545, test error 52.38
# Training model with  22 hidden variables
# Epoch     0, train loss 2.114913, train error 79.07,  test loss 2.053086, test error 78.40
# Epoch   100, train loss 1.281072, train error 43.00,  test loss 1.286247, test error 48.90
# Epoch   200, train loss 1.170817, train error 39.30,  test loss 1.348503, test error 49.28
# Epoch   300, train loss 1.116959, train error 38.60,  test loss 1.427779, test error 50.65
# Epoch   400, train loss 1.082523, train error 37.28,  test loss 1.479867, test error 50.65
# Epoch   500, train loss 1.057985, train error 36.78,  test loss 1.542892, test error 51.53
# Epoch   600, train loss 1.044666, train error 36.72,  test loss 1.596336, test error 52.08
# Epoch   700, train loss 1.017471, train error 35.68,  test loss 1.624207, test error 51.50
# Epoch   800, train loss 0.999150, train error 34.85,  test loss 1.686687, test error 52.33
# Epoch   900, train loss 0.994732, train error 34.38,  test loss 1.722545, test error 52.65
# Training model with  26 hidden variables
# Epoch     0, train loss 2.259774, train error 84.07,  test loss 2.263036, test error 84.10
# Epoch   100, train loss 1.201985, train error 40.58,  test loss 1.366124, test error 49.80
# Epoch   200, train loss 1.051633, train error 35.68,  test loss 1.431534, test error 49.95
# Epoch   300, train loss 0.975010, train error 32.28,  test loss 1.519722, test error 50.92
# Epoch   400, train loss 0.937278, train error 31.57,  test loss 1.633773, test error 51.33
# Epoch   500, train loss 0.892600, train error 29.72,  test loss 1.719502, test error 52.17
# Epoch   600, train loss 0.883103, train error 30.03,  test loss 1.804242, test error 52.50
# Epoch   700, train loss 0.878344, train error 30.30,  test loss 1.823280, test error 53.47
# Epoch   800, train loss 0.857152, train error 28.93,  test loss 1.898327, test error 52.95
# Epoch   900, train loss 0.838293, train error 28.05,  test loss 1.966137, test error 54.10
# Training model with  30 hidden variables
# Epoch     0, train loss 2.103195, train error 78.28,  test loss 2.065968, test error 76.82
# Epoch   100, train loss 1.113463, train error 37.45,  test loss 1.335223, test error 49.80
# Epoch   200, train loss 0.974369, train error 33.57,  test loss 1.498538, test error 50.78
# Epoch   300, train loss 0.877322, train error 28.93,  test loss 1.644350, test error 51.53
# Epoch   400, train loss 0.816293, train error 27.95,  test loss 1.798390, test error 52.67
# Epoch   500, train loss 0.785314, train error 26.75,  test loss 1.984891, test error 54.65
# Epoch   600, train loss 0.746907, train error 24.75,  test loss 2.123724, test error 54.25
# Epoch   700, train loss 0.701608, train error 22.97,  test loss 2.263581, test error 54.85
# Epoch   800, train loss 0.716661, train error 23.75,  test loss 2.391353, test error 54.12
# Epoch   900, train loss 0.682349, train error 22.55,  test loss 2.466111, test error 54.10
# Training model with  35 hidden variables
# Epoch     0, train loss 2.134364, train error 77.88,  test loss 2.087358, test error 77.00
# Epoch   100, train loss 1.000153, train error 32.70,  test loss 1.380538, test error 48.72
# Epoch   200, train loss 0.800171, train error 26.80,  test loss 1.737333, test error 52.10
# Epoch   300, train loss 0.665346, train error 22.05,  test loss 2.045268, test error 52.60
# Epoch   400, train loss 0.585582, train error 18.80,  test loss 2.352687, test error 53.42
# Epoch   500, train loss 0.567665, train error 19.22,  test loss 2.673546, test error 53.90
# Epoch   600, train loss 0.533184, train error 18.35,  test loss 2.998720, test error 55.12
# Epoch   700, train loss 0.497394, train error 17.18,  test loss 3.213998, test error 54.90
# Epoch   800, train loss 0.453369, train error 15.60,  test loss 3.481668, test error 55.55
# Epoch   900, train loss 0.425998, train error 14.78,  test loss 3.657588, test error 54.88
# Training model with  40 hidden variables
# Epoch     0, train loss 2.127260, train error 79.45,  test loss 2.080526, test error 77.82
# Epoch   100, train loss 0.892965, train error 28.18,  test loss 1.418134, test error 50.08
# Epoch   200, train loss 0.628023, train error 20.68,  test loss 1.875163, test error 51.70
# Epoch   300, train loss 0.469184, train error 15.15,  test loss 2.539004, test error 53.50
# Epoch   400, train loss 0.397678, train error 13.62,  test loss 3.190608, test error 53.58
# Epoch   500, train loss 0.325196, train error 10.60,  test loss 3.842140, test error 54.28
# Epoch   600, train loss 0.276601, train error 8.62,  test loss 4.594246, test error 55.50
# Epoch   700, train loss 0.274427, train error 9.50,  test loss 5.185071, test error 55.45
# Epoch   800, train loss 0.230010, train error 7.97,  test loss 5.757081, test error 55.35
# Epoch   900, train loss 0.310659, train error 11.22,  test loss 6.312134, test error 54.88
# Training model with  45 hidden variables
# Epoch     0, train loss 2.096608, train error 77.53,  test loss 2.078897, test error 77.10
# Epoch   100, train loss 0.808050, train error 25.10,  test loss 1.492781, test error 49.53
# Epoch   200, train loss 0.477133, train error 15.03,  test loss 2.212326, test error 52.60
# Epoch   300, train loss 0.298769, train error 9.00,  test loss 3.331919, test error 54.90
# Epoch   400, train loss 0.232709, train error 7.88,  test loss 4.579471, test error 54.62
# Epoch   500, train loss 0.158456, train error 4.93,  test loss 5.862577, test error 56.08
# Epoch   600, train loss 0.023376, train error 0.03,  test loss 7.124866, test error 56.28
# Epoch   700, train loss 0.012391, train error 0.00,  test loss 8.079237, test error 56.25
# Epoch   800, train loss 0.008406, train error 0.00,  test loss 8.729048, test error 56.22
# Epoch   900, train loss 0.006230, train error 0.00,  test loss 9.219002, test error 56.17
# Training model with  50 hidden variables
# Epoch     0, train loss 2.110942, train error 77.93,  test loss 2.085989, test error 77.75
# Epoch   100, train loss 0.700083, train error 21.47,  test loss 1.619152, test error 50.88
# Epoch   200, train loss 0.318956, train error 8.57,  test loss 2.707071, test error 53.05
# Epoch   300, train loss 0.169662, train error 4.28,  test loss 4.350262, test error 54.58
# Epoch   400, train loss 0.030957, train error 0.00,  test loss 6.016338, test error 55.15
# Epoch   500, train loss 0.014133, train error 0.00,  test loss 7.059954, test error 55.42
# Epoch   600, train loss 0.008857, train error 0.00,  test loss 7.735618, test error 55.35
# Epoch   700, train loss 0.006268, train error 0.00,  test loss 8.245882, test error 55.38
# Epoch   800, train loss 0.004810, train error 0.00,  test loss 8.654377, test error 55.55
# Epoch   900, train loss 0.003871, train error 0.00,  test loss 8.994786, test error 55.62
# Training model with  55 hidden variables
# Epoch     0, train loss 2.043200, train error 75.90,  test loss 1.982143, test error 75.57
# Epoch   100, train loss 0.632376, train error 19.25,  test loss 1.687692, test error 51.65
# Epoch   200, train loss 0.212620, train error 5.20,  test loss 3.165833, test error 55.17
# Epoch   300, train loss 0.040322, train error 0.00,  test loss 4.939012, test error 55.15
# Epoch   400, train loss 0.014295, train error 0.00,  test loss 5.984409, test error 55.20
# Epoch   500, train loss 0.008445, train error 0.00,  test loss 6.608204, test error 55.33
# Epoch   600, train loss 0.005736, train error 0.00,  test loss 7.058167, test error 55.47
# Epoch   700, train loss 0.004303, train error 0.00,  test loss 7.405458, test error 55.45
# Epoch   800, train loss 0.003401, train error 0.00,  test loss 7.696074, test error 55.47
# Epoch   900, train loss 0.002797, train error 0.00,  test loss 7.942145, test error 55.62
# Training model with  60 hidden variables
# Epoch     0, train loss 2.064628, train error 77.50,  test loss 2.032382, test error 78.12
# Epoch   100, train loss 0.502743, train error 14.82,  test loss 1.826633, test error 51.20
# Epoch   200, train loss 0.083333, train error 0.45,  test loss 3.590850, test error 54.17
# Epoch   300, train loss 0.017583, train error 0.00,  test loss 4.871515, test error 54.15
# Epoch   400, train loss 0.008667, train error 0.00,  test loss 5.544757, test error 54.42
# Epoch   500, train loss 0.005540, train error 0.00,  test loss 5.976826, test error 54.33
# Epoch   600, train loss 0.003955, train error 0.00,  test loss 6.303770, test error 54.42
# Epoch   700, train loss 0.003061, train error 0.00,  test loss 6.565132, test error 54.55
# Epoch   800, train loss 0.002461, train error 0.00,  test loss 6.773072, test error 54.45
# Epoch   900, train loss 0.002051, train error 0.00,  test loss 6.954272, test error 54.50
# Training model with  70 hidden variables
# Epoch     0, train loss 1.998789, train error 73.70,  test loss 1.930007, test error 74.53
# Epoch   100, train loss 0.357767, train error 9.53,  test loss 1.843045, test error 49.95
# Epoch   200, train loss 0.031026, train error 0.00,  test loss 3.393806, test error 52.33
# Epoch   300, train loss 0.010675, train error 0.00,  test loss 4.135760, test error 52.35
# Epoch   400, train loss 0.005900, train error 0.00,  test loss 4.547243, test error 52.47
# Epoch   500, train loss 0.003977, train error 0.00,  test loss 4.836170, test error 52.55
# Epoch   600, train loss 0.002958, train error 0.00,  test loss 5.054059, test error 52.70
# Epoch   700, train loss 0.002323, train error 0.00,  test loss 5.235565, test error 52.65
# Epoch   800, train loss 0.001897, train error 0.00,  test loss 5.383507, test error 52.78
# Epoch   900, train loss 0.001597, train error 0.00,  test loss 5.513550, test error 52.67
# Training model with  80 hidden variables
# Epoch     0, train loss 2.023729, train error 74.60,  test loss 1.941711, test error 73.93
# Epoch   100, train loss 0.236616, train error 4.20,  test loss 2.080210, test error 49.85
# Epoch   200, train loss 0.020079, train error 0.00,  test loss 3.433699, test error 50.92
# Epoch   300, train loss 0.007924, train error 0.00,  test loss 3.987308, test error 50.95
# Epoch   400, train loss 0.004673, train error 0.00,  test loss 4.314126, test error 50.72
# Epoch   500, train loss 0.003237, train error 0.00,  test loss 4.551531, test error 50.83
# Epoch   600, train loss 0.002435, train error 0.00,  test loss 4.734871, test error 50.85
# Epoch   700, train loss 0.001937, train error 0.00,  test loss 4.883293, test error 50.97
# Epoch   800, train loss 0.001597, train error 0.00,  test loss 5.009475, test error 51.05
# Epoch   900, train loss 0.001351, train error 0.00,  test loss 5.118321, test error 50.97
# Training model with  90 hidden variables
# Epoch     0, train loss 1.995867, train error 73.68,  test loss 1.927758, test error 74.28
# Epoch   100, train loss 0.165106, train error 1.70,  test loss 2.240243, test error 52.97
# Epoch   200, train loss 0.015384, train error 0.00,  test loss 3.357794, test error 53.17
# Epoch   300, train loss 0.006718, train error 0.00,  test loss 3.819402, test error 53.33
# Epoch   400, train loss 0.004074, train error 0.00,  test loss 4.103148, test error 52.97
# Epoch   500, train loss 0.002861, train error 0.00,  test loss 4.309515, test error 53.03
# Epoch   600, train loss 0.002170, train error 0.00,  test loss 4.468202, test error 53.12
# Epoch   700, train loss 0.001734, train error 0.00,  test loss 4.598144, test error 53.08
# Epoch   800, train loss 0.001433, train error 0.00,  test loss 4.708061, test error 53.12
# Epoch   900, train loss 0.001216, train error 0.00,  test loss 4.803562, test error 53.08
# Training model with 100 hidden variables
# Epoch     0, train loss 2.011127, train error 73.35,  test loss 1.979594, test error 75.28
# Epoch   100, train loss 0.099580, train error 0.12,  test loss 2.226569, test error 51.17
# Epoch   200, train loss 0.012357, train error 0.00,  test loss 3.129818, test error 51.30
# Epoch   300, train loss 0.005748, train error 0.00,  test loss 3.504830, test error 51.60
# Epoch   400, train loss 0.003584, train error 0.00,  test loss 3.739049, test error 51.85
# Epoch   500, train loss 0.002552, train error 0.00,  test loss 3.907964, test error 51.72
# Epoch   600, train loss 0.001952, train error 0.00,  test loss 4.040170, test error 51.88
# Epoch   700, train loss 0.001569, train error 0.00,  test loss 4.151195, test error 51.97
# Epoch   800, train loss 0.001304, train error 0.00,  test loss 4.243657, test error 52.12
# Epoch   900, train loss 0.001110, train error 0.00,  test loss 4.324890, test error 52.12
# Training model with 120 hidden variables
# Epoch     0, train loss 1.981590, train error 73.82,  test loss 1.904370, test error 75.28
# Epoch   100, train loss 0.051262, train error 0.00,  test loss 2.161387, test error 49.85
# Epoch   200, train loss 0.009549, train error 0.00,  test loss 2.757070, test error 49.95
# Epoch   300, train loss 0.004717, train error 0.00,  test loss 3.029509, test error 49.85
# Epoch   400, train loss 0.003004, train error 0.00,  test loss 3.202217, test error 49.83
# Epoch   500, train loss 0.002164, train error 0.00,  test loss 3.331800, test error 49.97
# Epoch   600, train loss 0.001673, train error 0.00,  test loss 3.433431, test error 49.80
# Epoch   700, train loss 0.001352, train error 0.00,  test loss 3.518172, test error 49.95
# Epoch   800, train loss 0.001129, train error 0.00,  test loss 3.590474, test error 49.92
# Epoch   900, train loss 0.000965, train error 0.00,  test loss 3.652611, test error 49.97
# Training model with 140 hidden variables
# Epoch     0, train loss 1.962530, train error 72.68,  test loss 1.892493, test error 74.07
# Epoch   100, train loss 0.037215, train error 0.00,  test loss 2.153141, test error 49.45
# Epoch   200, train loss 0.008305, train error 0.00,  test loss 2.617931, test error 49.22
# Epoch   300, train loss 0.004263, train error 0.00,  test loss 2.845165, test error 49.17
# Epoch   400, train loss 0.002769, train error 0.00,  test loss 2.993137, test error 49.08
# Epoch   500, train loss 0.002015, train error 0.00,  test loss 3.102900, test error 49.12
# Epoch   600, train loss 0.001565, train error 0.00,  test loss 3.190494, test error 49.30
# Epoch   700, train loss 0.001270, train error 0.00,  test loss 3.263937, test error 49.30
# Epoch   800, train loss 0.001064, train error 0.00,  test loss 3.326137, test error 49.38
# Epoch   900, train loss 0.000911, train error 0.00,  test loss 3.380952, test error 49.42
# Training model with 160 hidden variables
# Epoch     0, train loss 1.928329, train error 71.18,  test loss 1.852268, test error 71.68
# Epoch   100, train loss 0.027985, train error 0.00,  test loss 2.082297, test error 48.58
# Epoch   200, train loss 0.007127, train error 0.00,  test loss 2.474900, test error 48.38
# Epoch   300, train loss 0.003745, train error 0.00,  test loss 2.667744, test error 48.50
# Epoch   400, train loss 0.002470, train error 0.00,  test loss 2.798489, test error 48.33
# Epoch   500, train loss 0.001811, train error 0.00,  test loss 2.895898, test error 48.47
# Epoch   600, train loss 0.001415, train error 0.00,  test loss 2.972786, test error 48.47
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.037520, test error 48.47
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 3.092884, test error 48.53
# Epoch   900, train loss 0.000832, train error 0.00,  test loss 3.141504, test error 48.45
# Training model with 180 hidden variables
# Epoch     0, train loss 1.901109, train error 69.47,  test loss 1.831039, test error 71.82
# Epoch   100, train loss 0.024168, train error 0.00,  test loss 2.080084, test error 48.28
# Epoch   200, train loss 0.006550, train error 0.00,  test loss 2.440254, test error 48.50
# Epoch   300, train loss 0.003498, train error 0.00,  test loss 2.619001, test error 48.55
# Epoch   400, train loss 0.002316, train error 0.00,  test loss 2.739973, test error 48.53
# Epoch   500, train loss 0.001706, train error 0.00,  test loss 2.829869, test error 48.45
# Epoch   600, train loss 0.001336, train error 0.00,  test loss 2.902786, test error 48.35
# Epoch   700, train loss 0.001091, train error 0.00,  test loss 2.963217, test error 48.42
# Epoch   800, train loss 0.000918, train error 0.00,  test loss 3.015756, test error 48.38
# Epoch   900, train loss 0.000789, train error 0.00,  test loss 3.061324, test error 48.30
# Training model with 200 hidden variables
# Epoch     0, train loss 1.947911, train error 71.93,  test loss 1.876513, test error 72.45
# Epoch   100, train loss 0.021281, train error 0.00,  test loss 1.999887, test error 47.78
# Epoch   200, train loss 0.006106, train error 0.00,  test loss 2.313626, test error 47.78
# Epoch   300, train loss 0.003316, train error 0.00,  test loss 2.476902, test error 47.65
# Epoch   400, train loss 0.002212, train error 0.00,  test loss 2.584756, test error 47.60
# Epoch   500, train loss 0.001633, train error 0.00,  test loss 2.667228, test error 47.62
# Epoch   600, train loss 0.001282, train error 0.00,  test loss 2.733489, test error 47.53
# Epoch   700, train loss 0.001048, train error 0.00,  test loss 2.788825, test error 47.45
# Epoch   800, train loss 0.000882, train error 0.00,  test loss 2.836172, test error 47.42
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.877319, test error 47.42
# Training model with 250 hidden variables
# Epoch     0, train loss 1.864786, train error 67.55,  test loss 1.793704, test error 69.22
# Epoch   100, train loss 0.017106, train error 0.00,  test loss 1.909804, test error 46.90
# Epoch   200, train loss 0.005319, train error 0.00,  test loss 2.150168, test error 46.80
# Epoch   300, train loss 0.002958, train error 0.00,  test loss 2.280361, test error 47.05
# Epoch   400, train loss 0.001998, train error 0.00,  test loss 2.368803, test error 46.88
# Epoch   500, train loss 0.001487, train error 0.00,  test loss 2.435365, test error 46.95
# Epoch   600, train loss 0.001174, train error 0.00,  test loss 2.489918, test error 46.90
# Epoch   700, train loss 0.000963, train error 0.00,  test loss 2.534737, test error 46.90
# Epoch   800, train loss 0.000813, train error 0.00,  test loss 2.574028, test error 46.80
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.607761, test error 46.72
# Training model with 300 hidden variables
# Epoch     0, train loss 1.903069, train error 69.93,  test loss 1.799414, test error 71.07
# Epoch   100, train loss 0.014524, train error 0.00,  test loss 1.836583, test error 46.30
# Epoch   200, train loss 0.004822, train error 0.00,  test loss 2.058499, test error 46.55
# Epoch   300, train loss 0.002724, train error 0.00,  test loss 2.176955, test error 46.50
# Epoch   400, train loss 0.001852, train error 0.00,  test loss 2.258420, test error 46.40
# Epoch   500, train loss 0.001385, train error 0.00,  test loss 2.320264, test error 46.40
# Epoch   600, train loss 0.001097, train error 0.00,  test loss 2.371122, test error 46.38
# Epoch   700, train loss 0.000903, train error 0.00,  test loss 2.413352, test error 46.33
# Epoch   800, train loss 0.000764, train error 0.00,  test loss 2.450025, test error 46.28
# Epoch   900, train loss 0.000660, train error 0.00,  test loss 2.482265, test error 46.33
# Training model with 400 hidden variables
# Epoch     0, train loss 1.863294, train error 67.28,  test loss 1.798715, test error 69.43
# Epoch   100, train loss 0.011655, train error 0.00,  test loss 1.750325, test error 45.97
# Epoch   200, train loss 0.004180, train error 0.00,  test loss 1.924532, test error 46.05
# Epoch   300, train loss 0.002421, train error 0.00,  test loss 2.021085, test error 46.00
# Epoch   400, train loss 0.001668, train error 0.00,  test loss 2.088151, test error 45.95
# Epoch   500, train loss 0.001257, train error 0.00,  test loss 2.139672, test error 45.95
# Epoch   600, train loss 0.001001, train error 0.00,  test loss 2.182102, test error 45.90
# Epoch   700, train loss 0.000827, train error 0.00,  test loss 2.217396, test error 45.92
# Epoch   800, train loss 0.000702, train error 0.00,  test loss 2.248004, test error 45.92
# Epoch   900, train loss 0.000608, train error 0.00,  test loss 2.274782, test error 45.88

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
